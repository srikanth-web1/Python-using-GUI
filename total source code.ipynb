# %%
from tkinter import *
from tkinter import messagebox

#start of edit
from tkinter import *
import sys
import os
from PIL import ImageTk,Image

def every_100(text):
    final_text=""
    for i in range(0,len(text)):
        final_text+=text[i]
        if i%100==0 and i!=0:
            final_text+="\n"
    return final_text
def every_200(text):
    final_text=""
    for i in range(0,len(text)):
        final_text+=text[i]
        if i%190==0 and i!=0:
            final_text+="\n"
    return final_text


#Function for articles

def myfun():
    top= Tk()
    top.title("TECHBUZZ the online publication")
    top.geometry("1000x1000")
    
    texts=[]
    for i in range(0,3):
        with open(f"{i+20}.txt") as f:
            text=f.read()
            if i==0:
                texts.append(every_100(text))
            else:
                texts.append(every_100(text))
    g=Frame(top,width=900,height=200)
    Label(g, text="ARTICLE 1",font="lucida 30 bold",padx=40,bg="#000",fg="#0cb0cb").pack()
    Label(g,text=texts[0],padx=8, pady=8).pack()
    Label(g,text="Contact US",font="lucida 20 italic",pady=10,padx=40).pack()
    Label(g,text="Feel Free to contact us through the details provided,Great day!",font="lucida 10",pady=40,padx=40).pack()
    Label(g,text="Mobile: (+91)0124529687",font="lucida 10",pady=40,padx=40).pack(side="left")
    Label(g,text="Email:dhe@gmail.com",font="lucida 10",pady=40,padx=40).pack(side="left")
    Label(g,text="Address:26-15-41,Gandhi Nagar, Ladhak-400213.",font="lucida 10",pady=40,padx=40).pack(side="left")
    g.pack()
def myfun2():
    top= Tk()
    top.title("TECHBUZZ the online publication")
    top.geometry("1000x1000")
    
  
    
    texts=[]
    for i in range(0,3):
        with open(f"{i+20}.txt") as f:
            text=f.read()
            if i==0:
                texts.append(every_100(text))
            else:
                texts.append(every_100(text))
    g=Frame(top,width=900,height=200)
    Label(g, text="ARTICLE 2",font="lucida 30 bold",padx=40,bg="#000",fg="#0cb0cb").pack()
    Label(g,text=texts[1],padx=8, pady=8).pack()
    Label(g,text="Contact US",font="lucida 20 italic",pady=10,padx=40).pack()
    Label(g,text="Feel Free to contact us through the details provided,Great day!",font="lucida 10",pady=40,padx=40).pack()
    Label(g,text="Mobile: (+91)0124529687",font="lucida 10",pady=40,padx=40).pack(side="left")
    Label(g,text="Email:dhe@gmail.com",font="lucida 10",pady=40,padx=40).pack(side="left")
    Label(g,text="Address:26-15-41,Gandhi Nagar, Ladhak-400213.",font="lucida 10",pady=40,padx=40).pack(side="left")
    g.pack()
def myfun3():
    top= Tk()
    top.title("TECHBUZZ the online publication")
    top.geometry("1000x1000")
    
    texts=[]
    for i in range(0,3):
        with open(f"{i+20}.txt") as f:
            text=f.read()
            if i==0:
                texts.append(every_100(text))
            else:
                texts.append(every_100(text))
    g=Frame(top,width=900,height=200)
    Label(g, text="ARTICLE 3",font="lucida 30 bold",padx=40,bg="#000",fg="#0cb0cb").pack()
    Label(g,text=texts[2],padx=8, pady=8).pack()
    Label(g,text="Contact US",font="lucida 20 italic",pady=10,padx=40).pack()
    Label(g,text="Feel Free to contact us through the details provided,Great day!",font="lucida 10",pady=40,padx=40).pack()
    Label(g,text="Mobile: (+91)0124529687",font="lucida 10",pady=40,padx=40).pack(side="left")
    Label(g,text="Email:dhe@gmail.com",font="lucida 10",pady=40,padx=40).pack(side="left")
    Label(g,text="Address:26-15-41,Gandhi Nagar, Ladhak-400213.",font="lucida 10",pady=40,padx=40).pack(side="left")
    g.pack()
    
    
    
    
    
    

#function for articles end


def homepage():
    
    
    root= Tk()
    root.title("TECHBUZZ the online publication")
    root.geometry("1000x1000")

    texts=[]
    photos=[]
    for i in range(0,3):
        with open(f"{i+1}.txt") as f:
            text=f.read()
            if i==0:
                texts.append(every_100(text))
            else:
                texts.append(every_200(text))

        image=Image.open(f"{i+1}.png")
    #Toto resize
    
        image=image.resize((320,320),Image.ANTIALIAS)
   

        photos.append(ImageTk.PhotoImage(image))
   
    f0= Frame(root, width=800, height=70,bg="#000")
    Label(f0, text="TECHBUZZ the online publication",font="Helvetica 25 italic",fg="#1c1c1c").pack()
    f0.pack()
    Label(f0, text="DR.APJ ABDHUL KALAM",font="lucida 33 bold").pack()
    f0.pack()
    
    f1=Frame(root,width=900,height=200)
    Label(f1,text=texts[0],padx=22, pady=22).pack(side="left")
    '''Label(f1,image=photos[0],anchor="e").pack()''' #once remove the quotes to see the error
    f1.pack(anchor="w")
    
    
    f2=Frame(root,width=900,height=200)
    Label(f2, text="Article 1",font="lucida 10 bold",padx=40,bg="#000",fg="#0cb0cb").pack()
    Label(f2,text=texts[1],padx=8, pady=8).pack(side="left")
    f2.pack(anchor="w")
    
    Button(root,text="Read Article",command=myfun,anchor="e",bg="grey",fg="#fff").pack(side="top")
    f3=Frame(root,width=900,height=200,pady=12)
    Label(f3, text="Article 2",font="lucida 10 bold",padx=40,bg="#000",fg="#0cb0cb").pack()
    Label(f3,text=texts[1],padx=8, pady=8).pack(side="left")

    f3.pack(anchor="w")

    Button(root,text="Read Article",command=myfun2,anchor="e",bg="grey",fg="#fff").pack(side="top")

    f4=Frame(root,width=900,height=200,pady=12)
    Label(f4, text="Article 3",font="lucida 10 bold",padx=40,bg="#000",fg="#0cb0cb").pack()
    Label(f4,text=texts[1],padx=8, pady=8).pack(side="left")

    f4.pack(anchor="w")

    Button(root,text="Read Article",command=myfun3,anchor="e",bg="grey",fg="#fff").pack(side="top")

    






#end of edit







top= Tk()

Label(text = "TECHBUZZ the online publication",bg="pink",width="300",height="2",font=("calibri",13)).pack()

top.geometry("1000x1000")

def Autor():
    
    top=Toplevel()
    
    f1.pack_forget()
    f4=Frame(top)
    f4.pack()
    l1=Label(f4,text="hello world",font=13)
    l1.grid(row=0,column=1)
    
    
    
def mainscreen():
        
        top=Toplevel()
        top.geometry("1500x800")
    
        f1.pack_forget()
        f2=Frame(top)
        f2.pack()
        
        l1=Label(f2,text="TECHBUZZ is a national publishing company in india.",font=18)
        l1.grid(row=0,column=0)
        l2=Label(f2,text="it was one of the best book publishing company in india",font=18)
        l2.grid(row=1,column=0)
        l3=Label(f2,text="CEO of the company is Mr.John Wallen",font=10)
        l3.grid(row=2,column=0)
        l5=Label(f2,text="Headquarters of the company is located in Bengalore,India.",font=18)
        l5.grid(row=3,column=0)
        l7=Label(f2,text="Founder and co chancellor of TECHBUZZ is Mr.Samuel Justin.",font=18)
        l7.grid(row=4,column=0)
        l8=Label(f2,text="Our main theme is to publish the articles of different authors.",font=18)
        l8.grid(row=5,column=0)
           
        b=Button(f2,text="NEXT",fg="blue",command=homepage)
        b.grid(row=5,column=6)
        
def register():
     
    
    f1.pack_forget()
    
   
    f3=Frame(top)
    f3.pack()
    l7=Label(f3,text="NAME:")
    l7.grid(row=0,column=0)
    e7=Entry(f3)
    e7.grid(row=0,column=1)
    l8=Label(f3,text="MOBILE NUMBER:")
    l8.grid(row=1,column=0)
    e8=Entry(f3)
    e8.grid(row=1,column=1)
    l9=Label(f3,text="EMAIL ID:")
    l9.grid(row=2,column=0)
    e9=Entry(f3)
    e9.grid(row=2,column=1)
    l10=Label(f3,text="PASSWORD:")
    l10.grid(row=3,column=0)
    e10=Entry(f3,show="*")
    e10.grid(row=3,column=1)
    l10=Label(f3,text="re-type PASSWORD:")
    l10.grid(row=4,column=0)
    e10=Entry(f3,show="*")
    e10.grid(row=4,column=1)
    b_in=Button(f3,text="register",fg="blue",command=mainscreen)
    b_in.grid(row=4,column=2)
    

    
        

f1=Frame(top)
f1.pack()
l_name=Label(f1,text="username")
l_name.grid(row=0,column=0)
e_name=Entry(f1)
e_name.grid(row=0,column=1)
l_pass=Label(f1,text="password")
l_pass.grid(row=1,column=0)
e_pass=Entry(f1,show="*")
e_pass.grid(row=1,column=1)


b_login=Button(f1,text="login",fg="blue",command=mainscreen)
b_login.grid(row=1,column=2)




b_signup=Button(f1,text="create new account",fg="blue",command=register)
b_signup.grid(row=2,column=0)




top.title("online publication record")





top.mainloop()
